# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import mnist, fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Activation
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import load_model
import tensorflow.keras.backend as k
from tensorflow.keras.utils import get_custom_objects

import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#tf.compat.v1.disable_eager_execution()

# %%
# download the dataset
(x_train, y_train), (x_val, y_val) = mnist.load_data()

# %%
# image classes or categories
class_names = ['Zero', 'One', 'Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine']

# %%
print("Number of Training Samples: ", len(x_train))
print("Number of Validation Samples: ", len(x_val))
# Out:
# Number of Training Samples:  60000
# Number of Validation Samples:  10000

# %%
# shape of images
print("Shape of Training images: ", x_train.shape)
print("Shape of Validation images: ", x_val.shape)
# Out:
# Shape of Training images:  (60000, 28, 28)
# Shape of Validation images:  (10000, 28, 28)

# %%
# reshape for training and testing
x_train = x_train.reshape(60000, 28, 28, 1)
x_val = x_val.reshape(10000, 28, 28, 1)

# %%
# change data type
x_train = x_train.astype('float32')
x_val = x_val.astype('float32')

# %%
# normalize data into range 1-0
x_train /= 255.0
x_val /= 255.0

# %%
print("Training shape: ", x_train.shape)
print("Validation shape: ", x_val.shape)
# Out:
# Training shape:  (60000, 28, 28, 1)
# Validation shape:  (10000, 28, 28, 1)

# %%
# show some training images
fig = plt.figure(figsize = (20, 4))

for idx in range(20):
  ax = fig.add_subplot(2, 10, idx + 1, xticks = [], yticks = [])
  plt.imshow(x_train[idx].reshape(28, 28), cmap = 'gray')
  plt.title(class_names[y_train[idx]])

# %%
input_shape = (28, 28, 1)
batch_size = 32
epochs = 5

# %%
# create AlexNet model
model= Sequential()

# 1st Convolution Layer
model.add(Conv2D(filters = 96, kernel_size = (11, 11), input_shape = (28, 28, 1), strides = 4))

# 1st relue activation layer
model.add(Activation('relu'))

# 1st Maxpolling Layer
model.add(MaxPooling2D(pool_size = (2, 2)))

# 2nd Convolution Layer
model.add(Conv2D(filters = 256, kernel_size = (5, 5), padding = 'same'))

# 2nd relue activation layer
model.add(Activation('relu'))

# 2nd Maxpolling Layer
model.add(MaxPooling2D(pool_size = (2, 2)))

# 3rd Convolution Layer
model.add(Conv2D(filters = 384, kernel_size = (3, 3), padding = 'same'))

# 3rd relue activation layer
model.add(Activation('relu'))

# 4th Convolution Layer
model.add(Conv2D(filters = 384, kernel_size = (3, 3), padding = 'same'))

# 4th relue activation layer
model.add(Activation('relu'))

# 5th Convolution Layer
model.add(Conv2D(filters = 256, kernel_size = (3, 3), padding = 'same'))

# 5th relue activation layer
model.add(Activation('relu'))


# Flatten Layer
model.add(Flatten())

# 2nd Fully Connected lyer
model.add(Dense(units = 9216, activation = 'relu'))

# 3rd Fully Connected lyer
model.add(Dense(units = 4096, activation = 'relu'))

# 4th Fully Connected lyer
model.add(Dense(units = 4096, activation = 'relu'))

# 5th Fully Connected lyer
model.add(Dense(units = 10, activation = 'softmax'))

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 5, 5, 96)          11712
# _________________________________________________________________
# activation (Activation)      (None, 5, 5, 96)          0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 2, 2, 96)          0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 2, 2, 256)         614656
# _________________________________________________________________
# activation_1 (Activation)    (None, 2, 2, 256)         0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 1, 1, 384)         885120
# _________________________________________________________________
# activation_2 (Activation)    (None, 1, 1, 384)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 1, 1, 384)         1327488
# _________________________________________________________________
# activation_3 (Activation)    (None, 1, 1, 384)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 1, 1, 256)         884992
# _________________________________________________________________
# activation_4 (Activation)    (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 9216)              2368512
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              37752832
# _________________________________________________________________
# dense_2 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 60,667,594
# Trainable params: 60,667,594
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# compile the model
model.compile(optimizer = 'adam', metrics = ['accuracy'], loss = 'sparse_categorical_crossentropy')

# %%
# Fit the model on dataset
history = model.fit(x_train, y_train,
                    validation_data = (x_val, y_val),
                    batch_size = batch_size,
                    epochs = 20)
# Out:
# Epoch 1/20
# 1615/1875 [========================>.....] - ETA: 10s - loss: 0.7204 - accuracy: 0.7232

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# accuracy and loss of model on test data
orig_loss, orig_accuracy = model.evaluate(x_val[:1000], y_val[:1000])
print()
print("Model Accuracy on test images: ", round(orig_accuracy, 4))
print("Model Loss on test images: ", round(orig_loss, 4))
# Out:
# 32/32 [==============================] - 0s 5ms/step - loss: 0.1098 - accuracy: 0.9780
#
# Model Accuracy on test images:  0.978
# Model Loss on test images:  0.1098

# %%
# predict some testing images
predictions = model.predict(x_val)

# show test images
fig = plt.figure(figsize = (20, 4))
for idx in range(20):
  ax = fig.add_subplot(2, 10, idx + 1, xticks = [], yticks = [])
  plt.imshow(x_val[idx].reshape(28, 28), cmap = 'gray')
  
  if class_names[y_val[idx]] == class_names[np.argmax(predictions[idx])]:
    color = 'blue'
  else:
    color = 'red'

  plt.imshow(x_val[idx].reshape(28, 28), cmap = 'gray')
  plt.title(class_names[y_val[idx]] + ' [' + class_names[np.argmax(predictions[idx])] + ']', color =  color)

# %% [markdown]
# **Gradient Based Attack**

# %% [markdown]
# ## 1. Fast Gradient Sign Attack and Reconstruction of Adversarial Example

# %%
#!pip install foolbox
import foolbox
import eagerpy as ep

# %%
pred = model.predict(x_val[:1000])

label = []
for i in range(len(pred)):
  y_pred = np.argmax(pred[i])
  l = label.append(y_pred) 


labels = np.asarray(label)

images = tf.cast(x_val[:1000], dtype = tf.float32)
labels = tf.cast(labels, dtype = tf.int32)

images = ep.astensor(images)
labels = ep.astensor(labels)

print(images.shape)
print(labels.shape)
# Out:
# (1000, 28, 28, 1)
# (1000,)

# %%
# create fool Model
fmodel = foolbox.models.TensorFlowModel(model = model, bounds = (0, 255))

# set criteria
c = foolbox.criteria.Misclassification(labels)

eps = [0.3]

# create attack
attack = foolbox.attacks.FGSM()

# create adversarial example
raw_adv, adv_img, success = attack(fmodel, images, criterion = c, epsilons = 0.09)

# adversarial purtubation
perturb = adv_img - x_val[:1000]

# %%
adv_pred = model.predict(adv_img.numpy())
fig = plt.figure(figsize = (20, 4))

for idx in range(20):
  fig = plt.subplot(2, 10 , idx + 1, xticks = ([]), yticks = ([]))
  plt.imshow(np.clip(adv_img[idx].numpy().reshape(28, 28), 0, 1), cmap = 'gray')
  
  if class_names[int(np.argmax(adv_pred[idx]))] == class_names[y_val[idx]]:
    color = 'blue'
  else:
    color = 'red'
  
  plt.title(class_names[y_val[idx]] + " [" + class_names[int(np.argmax(adv_pred[idx]))] + "]", color = color)

# %%
# accuracy and loss of model on adversarial images
adv_loss, adv_accuracy = model.evaluate(adv_img.numpy(), y_val[:1000])
print()
print("Model Accuracy on test images: ", round(adv_accuracy, 4))
print("Model Loss on test images: ", round(adv_loss, 4))
# Out:
# 32/32 [==============================] - 0s 4ms/step - loss: 2.0835 - accuracy: 0.4430
#
# Model Accuracy on test images:  0.443
# Model Loss on test images:  2.0835

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# load denoising model to remove FGSM putrbation
d_model = tf.keras.models.load_model('./drive/My Drive/PhD_Thesis/Generative_Models/autoencoder_mnist_fgsm.h5')

# %%
# Restore adversarial images created due to FGSM attack 
denise_images =d_model.predict(adv_img.numpy())

# %%
# predict some restored images
predictions = model.predict(denise_images)

# show restored images
fig = plt.figure(figsize = (20, 4))
for idx in range(20):
  ax = fig.add_subplot(2, 10, idx + 1, xticks = [], yticks = [])
  
  if class_names[y_val[idx]] == class_names[np.argmax(predictions[idx])]:
    color = 'blue'
  else:
    color = 'red'

  plt.imshow(denise_images[idx].reshape(28, 28), cmap = 'gray')
  plt.title(class_names[y_val[idx]] + ' [' + class_names[np.argmax(predictions[idx])] + ']', color =  color)

# %%
# accuracy and loss of model on restored images
rest_loss, rest_accuracy = model.evaluate(denise_images, y_val[:1000])
print()
print("Model Accuracy on restored images: ", round(rest_accuracy, 4))
print("Model Loss on test images: ", round(rest_loss, 4))
# Out:
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1433 - accuracy: 0.9630
#
# Model Accuracy on restored images:  0.963
# Model Loss on test images:  0.1433

# %%
print('Sucess rate of Defence Model: ', round(rest_accuracy / orig_accuracy, 4))
# Out:
# Sucess rate of Defence Model:  0.9847

# %% [markdown]
# # 2. Basic Iterative Method (Attack) and Reconstruction of Adversarial Examples

# %%
pred = model.predict(x_val[:1000])

label = []
for i in range(len(pred)):
  y_pred = np.argmax(pred[i])
  l = label.append(y_pred) 


labels = np.asarray(label)

images = tf.cast(x_val[:1000], dtype = tf.float32)
labels = tf.cast(labels, dtype = tf.int32)

images = ep.astensor(images)
labels = ep.astensor(labels)

print(images.shape)
print(labels.shape)
# Out:
# (1000, 28, 28, 1)
# (1000,)

# %%
# create fool Model
fmodel = foolbox.models.TensorFlowModel(model = model, bounds = (0, 255))

# set criteria
c = foolbox.criteria.Misclassification(labels)

eps = [0.3]

# create attack
attack = foolbox.attacks.L2BasicIterativeAttack()

# create adversarial example
raw_adv, adv_img, success = attack(fmodel, images, criterion = c, epsilons = 1.2)

# adversarial purtubation
perturb = adv_img - x_val[:1000]

# %%
adv_pred = model.predict(adv_img.numpy())
fig = plt.figure(figsize = (20, 4))

for idx in range(20):
  fig = plt.subplot(2, 10 , idx + 1, xticks = ([]), yticks = ([]))
  plt.imshow(np.clip(adv_img[idx].numpy().reshape(28, 28), 0, 1), cmap = 'gray')
  
  if class_names[int(np.argmax(adv_pred[idx]))] == class_names[y_val[idx]]:
    color = 'blue'
  else:
    color = 'red'
  
  plt.title(class_names[y_val[idx]] + " [" + class_names[int(np.argmax(adv_pred[idx]))] + "]", color = color)

# %%
# accuracy and loss of model on adversarial images
adv_loss, adv_accuracy = model.evaluate(adv_img.numpy(), y_val[:1000])
print()
print("Model Accuracy on test images: ", round(adv_accuracy, 4))
print("Model Loss on test images: ", round(adv_loss, 4))
# Out:
# 32/32 [==============================] - 0s 4ms/step - loss: 5.0065 - accuracy: 0.3180
#
# Model Accuracy on test images:  0.318
# Model Loss on test images:  5.0065

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# load denoising model to remove FGSM putrbation
d_model = tf.keras.models.load_model('./drive/My Drive/PhD_Thesis/Generative_Models/autoencoder_mnist_bim.h5')

# %%
# Restore adversarial images created due to FGSM attack 
denise_images =d_model.predict(adv_img.numpy())

# %%
# predict some restored images
predictions = model.predict(denise_images)

# show restored images
fig = plt.figure(figsize = (20, 4))
for idx in range(20):
  ax = fig.add_subplot(2, 10, idx + 1, xticks = [], yticks = [])
  
  if class_names[y_val[idx]] == class_names[np.argmax(predictions[idx])]:
    color = 'blue'
  else:
    color = 'red'

  plt.imshow(denise_images[idx].reshape(28, 28), cmap = 'gray')
  plt.title(class_names[y_val[idx]] + ' [' + class_names[np.argmax(predictions[idx])] + ']', color =  color)

# %%
# accuracy and loss of model on restored images
rest_loss, rest_accuracy = model.evaluate(denise_images, y_val[:1000])
print()
print("Model Accuracy on restored images: ", round(rest_accuracy, 4))
print("Model Loss on test images: ", round(rest_loss, 4))
# Out:
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1453 - accuracy: 0.9560
#
# Model Accuracy on restored images:  0.956
# Model Loss on test images:  0.1453

# %%
print('Success of Defens Model: ', round(rest_accuracy / orig_accuracy, 4))
# Out:
# Success of Defens Model:  0.9775

# %% [markdown]
# #3. Projected Gradient Descent Attack and Reconstruction of Adverasarial Examples

# %%
pred = model.predict(x_val[:1000])

label = []
for i in range(len(pred)):
  y_pred = np.argmax(pred[i])
  l = label.append(y_pred) 


labels = np.asarray(label)

images = tf.cast(x_val[:1000], dtype = tf.float32)
labels = tf.cast(labels, dtype = tf.int32)

images = ep.astensor(images)
labels = ep.astensor(labels)

print(images.shape)
print(labels.shape)
# Out:
# (1000, 28, 28, 1)
# (1000,)

# %%
# create fool Model
fmodel = foolbox.models.TensorFlowModel(model = model, bounds = (0, 255))

# set criteria
c = foolbox.criteria.Misclassification(labels)

eps = [0.3]

# create attack
attack = foolbox.attacks.PGD()

# create adversarial example
raw_adv, adv_img, success = attack(fmodel, images, criterion = c, epsilons = 0.18)

# adversarial purtubation
perturb = adv_img - x_val[:1000]

# %%
adv_pred = model.predict(adv_img.numpy())
fig = plt.figure(figsize = (20, 4))

for idx in range(20):
  fig = plt.subplot(2, 10 , idx + 1, xticks = ([]), yticks = ([]))
  plt.imshow(np.clip(adv_img[idx].numpy().reshape(28, 28), 0, 1), cmap = 'gray')
  
  if class_names[int(np.argmax(adv_pred[idx]))] == class_names[y_val[idx]]:
    color = 'blue'
  else:
    color = 'red'
  
  plt.title(class_names[y_val[idx]] + " [" + class_names[int(np.argmax(adv_pred[idx]))] + "]", color = color)

# %%
# accuracy and loss of model on adversarial images
adv_loss, adv_accuracy = model.evaluate(adv_img.numpy(), y_val[:1000])
print()
print("Model Accuracy on test images: ", round(adv_accuracy, 4))
print("Model Loss on test images: ", round(adv_loss, 4))
# Out:
# 32/32 [==============================] - 0s 4ms/step - loss: 18.0447 - accuracy: 0.0150
#
# Model Accuracy on test images:  0.015
# Model Loss on test images:  18.0447

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# load denoising model to remove FGSM putrbation
d_model = tf.keras.models.load_model('./drive/My Drive/PhD_Thesis/Generative_Models/autoencoder_mnist_pgd.h5')

# %%
# Restore adversarial images created due to FGSM attack 
denise_images =d_model.predict(adv_img.numpy())

# %%
# predict some restored images
predictions = model.predict(denise_images)

# show restored images
fig = plt.figure(figsize = (20, 4))
for idx in range(20):
  ax = fig.add_subplot(2, 10, idx + 1, xticks = [], yticks = [])
  
  if class_names[y_val[idx]] == class_names[np.argmax(predictions[idx])]:
    color = 'blue'
  else:
    color = 'red'

  plt.imshow(denise_images[idx].reshape(28, 28), cmap = 'gray')
  plt.title(class_names[y_val[idx]] + ' [' + class_names[np.argmax(predictions[idx])] + ']', color =  color)

# %%
# accuracy and loss of model on restored images
rest_loss, rest_accuracy = model.evaluate(denise_images, y_val[:1000])
print()
print("Model Accuracy on restored images: ", round(rest_accuracy, 4))
print("Model Loss on test images: ", round(rest_loss, 4))
# Out:
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1425 - accuracy: 0.9610
#
# Model Accuracy on restored images:  0.961
# Model Loss on test images:  0.1425

# %%
print('Success of Defence Model: ', round(rest_accuracy / orig_accuracy, 4))
# Out:
# Success of Defence Model:  0.9826

# %% [markdown]
# #4. Deep Fool Attack

# %%
pred = model.predict(x_val[:1000])

label = []
for i in range(len(pred)):
  y_pred = np.argmax(pred[i])
  l = label.append(y_pred) 


labels = np.asarray(label)

images = tf.cast(x_val[:1000], dtype = tf.float32)
labels = tf.cast(labels, dtype = tf.int32)

images = ep.astensor(images)
labels = ep.astensor(labels)

print(images.shape)
print(labels.shape)
# Out:
# (1000, 28, 28, 1)
# (1000,)

# %%
# create fool Model
fmodel = foolbox.models.TensorFlowModel(model = model, bounds = (0, 255))

# set criteria
c = foolbox.criteria.Misclassification(labels)

eps = [0.3]

# create attack
attack = foolbox.attacks.L2DeepFoolAttack()

# create adversarial example
raw_adv, adv_img, success = attack(fmodel, images, criterion = c, epsilons = 2)

# adversarial purtubation
perturb = adv_img - x_val[:1000]

# %%
adv_pred = model.predict(adv_img.numpy())
fig = plt.figure(figsize = (20, 4))

for idx in range(20):
  fig = plt.subplot(2, 10 , idx + 1, xticks = ([]), yticks = ([]))
  plt.imshow(np.clip(adv_img[idx].numpy().reshape(28, 28), 0, 1), cmap = 'gray')
  
  if class_names[int(np.argmax(adv_pred[idx]))] == class_names[y_val[idx]]:
    color = 'blue'
  else:
    color = 'red'
  
  plt.title(class_names[y_val[idx]] + " [" + class_names[int(np.argmax(adv_pred[idx]))] + "]", color = color)

# %%
# accuracy and loss of model on adversarial images
adv_loss, adv_accuracy = model.evaluate(adv_img.numpy(), y_val[:1000])
print()
print("Model Accuracy on test images: ", round(adv_accuracy, 4))
print("Model Loss on test images: ", round(adv_loss, 4))
# Out:
# 32/32 [==============================] - 0s 4ms/step - loss: 2.3923 - accuracy: 0.3420
#
# Model Accuracy on test images:  0.342
# Model Loss on test images:  2.3923

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# load denoising model to remove FGSM putrbation
d_model = tf.keras.models.load_model('./drive/My Drive/PhD_Thesis/Generative_Models/autoencoder_mnist_dfa.h5')

# %%
# Restore adversarial images created due to FGSM attack 
denise_images =d_model.predict(adv_img.numpy())

# %%
# predict some restored images
predictions = model.predict(denise_images)

# show restored images
fig = plt.figure(figsize = (20, 4))
for idx in range(20):
  ax = fig.add_subplot(2, 10, idx + 1, xticks = [], yticks = [])
  
  if class_names[y_val[idx]] == class_names[np.argmax(predictions[idx])]:
    color = 'blue'
  else:
    color = 'red'

  plt.imshow(denise_images[idx].reshape(28, 28), cmap = 'gray')
  plt.title(class_names[y_val[idx]] + ' [' + class_names[np.argmax(predictions[idx])] + ']', color =  color)

# %%
# accuracy and loss of model on restored images
rest_loss, rest_accuracy = model.evaluate(denise_images, y_val[:1000])
print()
print("Model Accuracy on restored images: ", round(rest_accuracy, 4))
print("Model Loss on test images: ", round(rest_loss, 4))
# Out:
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1202 - accuracy: 0.9710
#
# Model Accuracy on restored images:  0.971
# Model Loss on test images:  0.1202

# %%
print('Success of Defence Model: ', round(rest_accuracy / orig_accuracy, 4))
# Out:
# Success of Defence Model:  0.9928

# %% [markdown]
# # 5. Carlini and Wanger Attack

# %%
#!pip install foolbox
import foolbox
import eagerpy as ep

# %%
pred = model.predict(x_val[:1000])

label = []
for i in range(len(pred)):
  y_pred = np.argmax(pred[i])
  l = label.append(y_pred) 


labels = np.asarray(label)

images = tf.cast(x_val[:1000], dtype = tf.float32)
labels = tf.cast(labels, dtype = tf.int32)

images = ep.astensor(images)
labels = ep.astensor(labels)

print(images.shape)
print(labels.shape)
# Out:
# (1000, 28, 28, 1)
# (1000,)

# %%
# create fool Model
fmodel = foolbox.models.TensorFlowModel(model = model, bounds = (0, 255))

# set criteria
c = foolbox.criteria.Misclassification(labels)

eps = [0.3]

# create attack
attack = foolbox.attacks.L2CarliniWagnerAttack()

# create adversarial example
raw_adv, adv_img, success = attack(fmodel, images, criterion = c, epsilons = 5)

# adversarial purtubation
perturb = adv_img - x_val[:1000]

# %%
adv_pred = model.predict(adv_img[:1000].numpy())
fig = plt.figure(figsize = (20, 4))

for idx in range(20):
  fig = plt.subplot(2, 10 , idx + 1, xticks = ([]), yticks = ([]))
  plt.imshow(np.clip(adv_img[idx].numpy().reshape(28, 28), 0, 1), cmap = 'gray')
  
  if class_names[int(np.argmax(adv_pred[idx]))] == class_names[y_val[idx]]:
    color = 'blue'
  else:
    color = 'red'
  
  plt.title(class_names[y_val[idx]] + " [" + class_names[int(np.argmax(adv_pred[idx]))] + "]", color = color)

# %%
# accuracy and loss of model on adversarial images
adv_loss, adv_accuracy = model.evaluate(adv_img.numpy(), y_val[:1000])
print()
print("Model Accuracy on test images: ", round(adv_accuracy, 4))
print("Model Loss on test images: ", round(adv_loss, 4))
# Out:
# 32/32 [==============================] - 0s 4ms/step - loss: 0.9653 - accuracy: 0.2560
#
# Model Accuracy on test images:  0.256
# Model Loss on test images:  0.9653

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# load denoising model to remove FGSM putrbation
d_model = tf.keras.models.load_model('./drive/My Drive/PhD_Thesis/Generative_Models/mnist_cwa.h5')

# %%
# Restore adversarial images created due to FGSM attack 
denise_images =d_model.predict(adv_img.numpy())

# %%
# predict some restored images
predictions = model.predict(denise_images)

# show restored images
fig = plt.figure(figsize = (20, 4))
for idx in range(20):
  ax = fig.add_subplot(2, 10, idx + 1, xticks = [], yticks = [])
  
  if class_names[y_val[idx]] == class_names[np.argmax(predictions[idx])]:
    color = 'blue'
  else:
    color = 'red'

  plt.imshow(denise_images[idx].reshape(28, 28), cmap = 'gray')
  plt.title(class_names[y_val[idx]] + ' [' + class_names[np.argmax(predictions[idx])] + ']', color =  color)

# %%
# accuracy and loss of model on restored images
rest_loss, rest_accuracy = model.evaluate(denise_images, y_val[:1000])
print()
print("Model Accuracy on restored images: ", round(rest_accuracy, 4))
print("Model Loss on test images: ", round(rest_loss, 4))
# Out:
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1533 - accuracy: 0.9610
#
# Model Accuracy on restored images:  0.961
# Model Loss on test images:  0.1533

# %%
print('Sucess rate of Defence Model: ', round(rest_accuracy / orig_accuracy, 4))
# Out:
# Sucess rate of Defence Model:  0.9826

# %% [markdown]
# # 6. Spatial attack and Reconstruction of Adverasarial Examples

# %%
pred = model.predict(x_val)

label = []
for i in range(len(pred)):
  y_pred = np.argmax(pred[i])
  l = label.append(y_pred) 


labels = np.asarray(label)

images = tf.cast(x_val, dtype = tf.float32)
labels = tf.cast(labels, dtype = tf.int32)

images = ep.astensor(images)
labels = ep.astensor(labels)

print(images.shape)
print(labels.shape)
# Out:
# (10000, 28, 28, 1)
# (10000,)

# %%
# create fool Model
fmodel = foolbox.models.TensorFlowModel(model = model, bounds = (0, 255))

# set criteria
c = foolbox.criteria.Misclassification(labels)

# create attack
attack = foolbox.attacks.SpatialAttack()

# create adversarial example
raw_adv, adv_img, success = attack(fmodel, images, criterion = c)

# adversarial purtubation
perturb = adv_img - x_val

# %%
adv_pred = model.predict(adv_img.numpy())
fig = plt.figure(figsize = (20, 4))

for idx in range(20):
  fig = plt.subplot(2, 10 , idx + 1, xticks = ([]), yticks = ([]))
  plt.imshow(np.clip(adv_img[idx].numpy().reshape(28, 28), 0, 1), cmap = 'gray')
  
  if class_names[int(np.argmax(adv_pred[idx]))] == class_names[y_val[idx]]:
    color = 'blue'
  else:
    color = 'red'
  
  plt.title(class_names[y_val[idx]] + " [" + class_names[int(np.argmax(adv_pred[idx]))] + "]", color = color)

# %%
# accuracy and loss of model on adversarial images
adv_loss, adv_accuracy = model.evaluate(adv_img.numpy(), y_val)
print()
print("Model Accuracy on test images: ", round(adv_accuracy, 4))
print("Model Loss on test images: ", round(adv_loss, 4))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 3.8511 - accuracy: 0.0161
#
# Model Accuracy on test images:  0.0161
# Model Loss on test images:  3.8511

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# load denoising model to remove putrbation
d_model = tf.keras.models.load_model('./drive/My Drive/PhD_Thesis/Generative_Models/autoencoder_mnist_spa.h5')

# %%
# Restore adversarial images created due to FGSM attack 
denise_images =d_model.predict(adv_img.numpy())

# %%
# predict some restored images
predictions = model.predict(denise_images)

# show restored images
fig = plt.figure(figsize = (20, 4))
for idx in range(20):
  ax = fig.add_subplot(2, 10, idx + 1, xticks = [], yticks = [])
  
  if class_names[y_val[idx]] == class_names[np.argmax(predictions[idx])]:
    color = 'blue'
  else:
    color = 'red'

  plt.imshow(denise_images[idx].reshape(28, 28), cmap = 'gray')
  plt.title(class_names[y_val[idx]] + ' [' + class_names[np.argmax(predictions[idx])] + ']', color =  color)

# %%
# accuracy and loss of model on restored images
rest_loss, rest_accuracy = model.evaluate(denise_images, y_val)
print()
print("Model Accuracy on restored images: ", round(rest_accuracy, 4))
print("Model Loss on test images: ", round(rest_loss, 4))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1794 - accuracy: 0.9647
#
# Model Accuracy on restored images:  0.9647
# Model Loss on test images:  0.1794

# %%
print('Success of Defence Model: ', round(rest_accuracy / orig_accuracy, 4))
# Out:
# Success of Defence Model:  0.9751
